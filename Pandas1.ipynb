# %%
import pandas as pd

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data_panda.csv")
df=df1.head(169)
print(df.info())
print('---------------------------------------------------------------------------------------------')
print(df.to_string())

# %%
df.head()

# %%
df.tail()

# %%
#df.dropna(inplace=True)
#df

# %%
x = df["Maxpulse"].mean()
y = df["Calories"].mean()
print(x)
print(y)
df["Maxpulse"].fillna(x,inplace=True)
df["Calories"].fillna(y,inplace=True)
df.head(10)

# %%
print(df.loc[[2,5,7],["Calories","Maxpulse"]])

# %%
print(df.loc[[3,5,7],:])

# %%
df.iloc[0,1]

# %%
df.iloc[:,:]

# %%
df.iloc[0:9,:]

# %%
df.iloc[0:9,:-1]

# %%
df.iloc[[0,1]]

# %%
for x in df.index:
  if df.loc[x,"Duration"]>80:
    df.loc[x,"Duration"]=80
df

# %%
# Removing
for x in df.index:
  if df.loc[x,"Duration"]>80:
    df.drop(x,inplace=True)
df

# %%
# Removing Duplictes -->
df.drop_duplicates(inplace=True)

# %%
print('😎')
# Out:
# 😎
